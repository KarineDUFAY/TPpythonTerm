# %% [markdown]
# Bienvenue dans cette activité informatique. Je vous propose ici d'utiliser le langage Python et quelques unes de ses bibliothèques scientifiques. Il n'est pas nécessaire d'avoir de grandes connaissances en python, on se laisse guider pour comprendre le code !
#
# On peut Exécuter une cellule : il suffit de sélectionner la cellule et d'appuyer sur le bouton Exécuter ou bien SHIFT+ENTER (ou MAJ+ENTRÉE).

# %%
# On importe les librairies utiles
import numpy as np
import matplotlib.pyplot as plt

# Points de mesure
c, pH = [concentrations suivies d'une virgules], [pH correspondants suivis d'une virgule]

# %%
# Trace les points expémimentaux 
plt.xlabel('indiquer titre et unité axes des x')
plt.ylabel('titre axe des y')
plt.title('titre du graphique')
plt.scatter(x=COMPLETER, y=COMPLETER, marker='+', label='Mesures')
a=plt.show()

# %%
# Trace du modele théorique
cth = np.arange(1e-4, 1, 0.0001)
pHth = -np.log10(cth)
plt.plot(cth, pHth, color='red', label='Modelisation')
plt.legend()
plt.show()

# %%
# Supperposition modèle et expérience
plt.xlabel('Concentration en quantite de matiere c (mol/L)')
plt.ylabel('pH de la solution')
plt.title('Evolution du pH en fonction de la concentration en ion H3O+')
# On recopie les lignes de code pour tracer les deux graphiques
plt.scatter(x=COMPLETER, y=COMPLETER, marker='+', label='Mesures')
cth = COMPLETER
pHth = COMPLETER
plt.plot(COMPLETER, COMPLETER, color='red', label='Modelisation')
a=plt.legend()
